# %%
# Peter Nelson 15/11/19

# Code for Dissertation importing Data from xls files created from M files from FASTBLADE Simulink Model outputs.

# %%
import pandas as pd
import numpy as np
time_data = pd.read_excel(r"C:\Users\Peter's 2nd Laptop\Documents\readintopython.xlsx", sheet_name='TimeSeries')
non_time_data= pd.read_excel(r"C:\Users\Peter's 2nd Laptop\Documents\readintopython.xlsx", sheet_name='NotTimeSeries')
print(time_data)

#consider if index_col=0 is of any value??
# Out:
#         Time     Desired      Measured  CrossFlow1        Moment    Flowrate  \
# 0      0.000  440.000000  2.148963e-13    0.000000  3.342461e-11    0.000000
# 1      0.005  440.009771  6.218516e+00    1.958904  1.381789e+02  -85.155646
# 2      0.010  440.039082  4.468647e+00    1.596810  8.697266e+01   25.370804
# 3      0.015  440.087932  3.585874e+00   11.913634  7.202326e+01  120.711643
# 4      0.020  440.156316  3.121082e+00   17.154644  6.584864e+01  173.766389
# 5      0.025  440.244228  3.230573e+00   22.868362  6.735417e+01  172.350907
# 6      0.030  440.351659  3.796862e+00   28.316536  7.796226e+01  141.650416
# 7      0.035  440.478601  4.313311e+00   33.368235  9.327456e+01  104.079848
# 8      0.040  440.625042  4.695820e+00   37.270388  1.067566e+02   70.442216
# 9      0.045  440.790969  4.984398e+00   38.005048  1.165336e+02   50.005829
# 10     0.050  440.976368  5.132176e+00   34.864685  1.218593e+02   47.911142
# ...

# %%
nbp=non_time_data['nbp']
print(nbp)
type(nbp)
# Out:
# 0    6
# Name: nbp, dtype: int64
# pandas.core.series.Series

# %%
time=time_data['Time']
print(time)
# Out:
# 0        0.000
# 1        0.005
# 2        0.010
# 3        0.015
# 4        0.020
# 5        0.025
# 6        0.030
# 7        0.035
# 8        0.040
# 9        0.045
# 10       0.050
# 11       0.055
# 12       0.060
# 13       0.065
# 14       0.070
# 15       0.075
# 16       0.080
# 17       0.085
# 18       0.090
# 19       0.095
# 20       0.100
# 21       0.105
# 22       0.110
# 23       0.115
# 24       0.120
# 25       0.125
# 26       0.130
# 27       0.135
# 28       0.140
# 29       0.145
#          ...
# 6637    33.185
# 6638    33.190
# 6639    33.195
# 6640    33.200
# 6641    33.205
# 6642    33.210
# 6643    33.215
# 6644    33.220
# 6645    33.225
# 6646    33.230
# 6647    33.235
# 6648    33.240
# 6649    33.245
# 6650    33.250
# 6651    33.255
# 6652    33.260
# 6653    33.265
# 6654    33.270
# 6655    33.275
# 6656    33.280
# 6657    33.285
# 6658    33.290
# 6659    33.295
# 6660    33.300
# 6661    33.305
# 6662    33.310
# 6663    33.315
# ...
