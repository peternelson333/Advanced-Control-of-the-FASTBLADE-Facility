# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\Peter's 2nd Laptop\Documents\MATLAB\FB again\Matlab Code No Contraints\testdata.xlsx")

# %%
print(data)
# Out:
#     radial position        Fx       Fy
# 0          0.000000  1241.850 -228.450
# 1        205.128205  1230.165 -230.970
# 2        615.384615  1227.285 -224.010
# 3       1025.641026  1215.285 -215.760
# 4       1435.897436  1194.600 -206.355
# 5       1846.153846  1165.680 -195.930
# 6       2256.410256  1128.990 -184.605
# 7       2666.666667  1084.965 -172.515
# 8       3076.923077  1034.055 -159.795
# 9       3487.179487   976.695 -146.565
# 10      3897.435897   913.350 -132.945
# 11      4307.692308   844.470 -119.085
# 12      4717.948718   770.505 -105.105
# 13      5128.205128   691.875  -91.140
# 14      5538.461538   609.060  -77.310
# 15      5948.717949   522.495  -63.765
# 16      6358.974359   432.630  -50.610
# 17      6769.230769   339.915  -37.980
# 18      7179.487179   244.800  -26.010
# 19      7589.743590   147.720  -14.835
# 20      8000.000000    49.125   -4.575

# %%
index=data.index
columns=data.columns
values=data.values

# %%
data['Fx'].mean()
# Out:
# 812.6435714285714

# %%
rad_pos=data['radial position']
print (rad_pos)
type(rad_pos)
# Out:
# 0        0.000000
# 1      205.128205
# 2      615.384615
# 3     1025.641026
# 4     1435.897436
# 5     1846.153846
# 6     2256.410256
# 7     2666.666667
# 8     3076.923077
# 9     3487.179487
# 10    3897.435897
# 11    4307.692308
# 12    4717.948718
# 13    5128.205128
# 14    5538.461538
# 15    5948.717949
# 16    6358.974359
# 17    6769.230769
# 18    7179.487179
# 19    7589.743590
# 20    8000.000000
# Name: radial position, dtype: float64
# 82051.28205128206

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(data['Fx'],data['Fy'])
ax.set_xlabel('Fx')
ax.set_ylabel('Fy')
ax.set_title('plot practice')
# Out:
# Text(0.5, 1.0, 'plot practice')

# %%
data.head()
# Out:
#    radial position        Fx       Fy
# 0         0.000000  1241.850 -228.450
# 1       205.128205  1230.165 -230.970
# 2       615.384615  1227.285 -224.010
# 3      1025.641026  1215.285 -215.760
# 4      1435.897436  1194.600 -206.355

# %%
import scipy.io
data = scipy.io.loadmat('INERA001',squeeze_me=True)
mat=scipy.io.loadmat('INERA001')
type(data)
# Out:
# dict

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Mon Sep  2 16:43:49 2019',
#  '__version__': '1.0',
#  '__globals__': [],
#  'INERA001': array(('INERA001', array((array((0.3, 880, 0.5, 'Sine', 2, 0.065, 0, 0.05, 1, 6, 3, 4, 4, 0.075, 0.05, 1, 2.203, 0.5),
# ...

# %%
data['INERA001']
# Out:
# array(('INERA001', array((array((0.3, 880, 0.5, 'Sine', 2, 0.065, 0, 0.05, 1, 6, 3, 4, 4, 0.075, 0.05, 1, 2.203, 0.5),
#       dtype=[('inputFreq', 'O'), ('Force', 'O'), ('Rvalue', 'O'), ('Wavetype', 'O'), ('control_mode', 'O'), ('pid_p', 'O'), ('pid_d', 'O'), ('pid_i', 'O'), ('controlPower', 'O'), ('massCoef', 'O'), ('stiffCoef', 'O'), ('npumps', 'O'), ('nrams', 'O'), ('pRadius', 'O'), ('rRadius', 'O'), ('Gain', 'O'), ('Rotational_inertia_kgm2', 'O'), ('Torque_control_gain', 'O')]), 'FASTBLADE_10_Flush', 6, 33.333333333333336, 3.3333333333333335, 2296.358854811871, 0.005, array((array([3, 4, 5, 6], dtype=uint8), array([1, 1, 1, 1, 1, 1], dtype=uint8), array([0.      , 0.      , 0.0642  , 0.604802, 0.673803, 0.610202]), array([1.475, 1.475, 1.475, 1.475, 1.475, 1.475]), array([1.        , 0.8799844 , 0.7579106 , 0.60889334, 0.45221947,
#        0.30076398]), array([1188.8343788 ,  920.60070434,  682.90032627,  440.76165725,
#         243.11954262,  107.54073644])),
# ...

# %%
mat['mat']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-26d9c0163bbb> in <module>
# ----> 1 mat['mat']
#
# KeyError: 'mat'

# %%
datanew = scipy.io.loadmat('INERA001',mat_dtype=True)
datanew['INERA001']
# Out:
# array([[(array(['INERA001'], dtype='<U8'), array([[(array([[(array([[0.3]]), array([[880.]]), array([[0.5]]), array(['Sine'], dtype='<U4'), array([[2.]]), array([[0.065]]), array([[0.]]), array([[0.05]]), array([[1.]]), array([[6.]]), array([[3.]]), array([[4.]]), array([[4.]]), array([[0.075]]), array([[0.05]]), array([[1.]]), array([[2.203]]), array([[0.5]]))]],
# ...

# %%
scipy.io.loadmat('INERA001',struct_as_record=False)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Mon Sep  2 16:43:49 2019',
#  '__version__': '1.0',
#  '__globals__': [],
#  'INERA001': array([[<scipy.io.matlab.mio5_params.mat_struct object at 0x000001B00B59C7B8>]],
#        dtype=object)}

# %%
scipy.io.loadmat
